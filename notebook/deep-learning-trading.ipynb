# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Trading-Instrument" data-toc-modified-id="Trading-Instrument-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Trading Instrument</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#History" data-toc-modified-id="History-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>History</a></span></li><li><span><a href="#Time-step" data-toc-modified-id="Time-step-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Time step</a></span></li></ul></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Initialisation" data-toc-modified-id="Initialisation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Initialisation</a></span><ul class="toc-item"><li><span><a href="#Select-Currency-Pair" data-toc-modified-id="Select-Currency-Pair-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Select Currency Pair</a></span></li><li><span><a href="#Connect-to-Oanda-API" data-toc-modified-id="Connect-to-Oanda-API-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Connect to Oanda API</a></span></li><li><span><a href="#Select-Data-History" data-toc-modified-id="Select-Data-History-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Select Data History</a></span></li><li><span><a href="#Select-Parameters" data-toc-modified-id="Select-Parameters-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Select Parameters</a></span></li></ul></li><li><span><a href="#Data-Exploratory" data-toc-modified-id="Data-Exploratory-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Exploratory</a></span></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Feature Selection</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Target-Labeling" data-toc-modified-id="Target-Labeling-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Target Labeling</a></span></li><li><span><a href="#Data-Preparation-for-Model-Training" data-toc-modified-id="Data-Preparation-for-Model-Training-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Data Preparation for Model Training</a></span><ul class="toc-item"><li><span><a href="#Out-of-Sample-dataset-for-Testing" data-toc-modified-id="Out-of-Sample-dataset-for-Testing-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Out-of-Sample dataset for Testing</a></span></li><li><span><a href="#Dataset-for-Training-and-Validation" data-toc-modified-id="Dataset-for-Training-and-Validation-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Dataset for Training and Validation</a></span></li><li><span><a href="#Normalising-the-datasets" data-toc-modified-id="Normalising-the-datasets-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Normalising the datasets</a></span></li><li><span><a href="#Resampling-the-Training-dataset" data-toc-modified-id="Resampling-the-Training-dataset-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Resampling the Training dataset</a></span></li><li><span><a href="#Prepare-Training-and-Validation-dataset-for-GridSearch" data-toc-modified-id="Prepare-Training-and-Validation-dataset-for-GridSearch-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Prepare Training and Validation dataset for GridSearch</a></span></li><li><span><a href="#Finalising-the-Datasets" data-toc-modified-id="Finalising-the-Datasets-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Finalising the Datasets</a></span></li></ul></li><li><span><a href="#Building-Deep-Learning-Model" data-toc-modified-id="Building-Deep-Learning-Model-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Building Deep Learning Model</a></span><ul class="toc-item"><li><span><a href="#Defining-model-structure" data-toc-modified-id="Defining-model-structure-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Defining model structure</a></span></li><li><span><a href="#Hyperparameter-Tuning" data-toc-modified-id="Hyperparameter-Tuning-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Hyperparameter Tuning</a></span></li><li><span><a href="#Building-Best-Model" data-toc-modified-id="Building-Best-Model-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Building Best Model</a></span></li><li><span><a href="#Model-Performance" data-toc-modified-id="Model-Performance-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Model Performance</a></span><ul class="toc-item"><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#Classification-Report" data-toc-modified-id="Classification-Report-9.4.2"><span class="toc-item-num">9.4.2&nbsp;&nbsp;</span>Classification Report</a></span></li></ul></li></ul></li><li><span><a href="#Trading-Performance" data-toc-modified-id="Trading-Performance-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Trading Performance</a></span><ul class="toc-item"><li><span><a href="#On-Training-Data" data-toc-modified-id="On-Training-Data-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>On Training Data</a></span></li><li><span><a href="#On-Out-of-Sample-Data" data-toc-modified-id="On-Out-of-Sample-Data-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>On Out-of-Sample Data</a></span></li></ul></li><li><span><a href="#Concluding-Remarks" data-toc-modified-id="Concluding-Remarks-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Concluding Remarks</a></span></li></ul></div>

# %% [markdown]
# # Algorithmic Trading with Deep Learning
#
# ## Summary
# This notebook trains a deep learning model to predict the direction a trading bot should take in the current time step so as to achieve positive return in next time step.  In other words, the model predicts whether the asset return is positive or negative in the next time step and take action to long or short position based on analytics known up to the current point in time.
#
# ### Trading Instrument
# Currency pair **USDJPY** is used here.  Bid ask spread of this instrument is used in estimating the transaction cost.  USDJPY has the lowest spread when compared with other currency pairs.
#
# ### Data
# Using Oanda API for historical data download and executing trades.
#
# ### History
# 90 days of latest historical prices.  The data is split with a ratio of 4:1 to training data and out-of-sample data.
#
# ### Time step
# 15-minute time step.  This means the algorithm will make a decision to take a long or short position.  Transaction cost is only taken in consideration when there is a switch in position's direction.
#
# ---

# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import math
import time
import numpy as np
import pandas as pd
import datetime as dt

SEED = 3333
np.random.seed(SEED)

# Import the plotting library
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

## Changing the default settings
pd.options.display.max_columns = 50
plt.rcParams.update({'figure.figsize':(15,6), 'figure.dpi':60})
plt.style.use('fivethirtyeight')

# %%
import sys  
sys.path.append('../helper') 
sys.path.append('../src') 

from edge import *
from edge_risk_kit import *
import edge_risk_kit as erk

# %%
from ta import add_all_ta_features
from ta.utils import dropna

# %%
MODEL_FOLDER = '../model/'
OUTPUT_FOLDER = '../output/'

# %% [markdown]
# ## Initialisation
# ### Select Currency Pair

# %%
spread_info = {
    'EUR_USD' : 0.00008,
    'GBP_USD' : 0.00012,
    'USD_JPY' : 0.008,
    'USD_ZAR' : 0.01059,
    'SPX500_USD' : 0.3
}

# %% [markdown]
# Spread will be used to calculate the transaction cost when assessing model performance.

# %%
instrument = 'USD_JPY'
spread = spread_info[instrument]
spread
# Out:
# 0.008

# %% [markdown]
# ### Connect to Oanda API
#
# Oanda credentials stored in config file.  You can create your own API login.

# %%
import tpqoa
# %time api = tpqoa.tpqoa('../config/pyalgo.cfg')
# Out:
# CPU times: user 1.32 ms, sys: 0 ns, total: 1.32 ms
# Wall time: 2.68 ms

# %%
# api.get_account_summary()
# api.get_instruments()

# %% [markdown]
# ### Select Data History
#
# Parameters to note
# - start and end: Historial period to use
# - gradularity: data resample period, aka bar size
# - price: M for mid price
# - window: lookback history (number of bars)
# - lags: number of features for model training

# %% [markdown]
# ### Select Parameters
# - 90 days of history
# - 15 minute sample size
# - 48 lookback samples
# - 6 lagged features

# %%
HISTORY = 90
BAR_LENGTH = '15T'
WINDOW = 48
LAGS = 6
PERIODS_PER_YEAR = 4*24*252
RISK_FREE_RATE = 0.02
PROBABILITY = 0.65

# %%
# help(api.get_history)

# %% [markdown]
# Using past 90 days of 1-minute data from Oanda and then resample the data to 15-minute time step.  Please note Oanda time zone is UTC.  Data availability is based on UTC timezone.

# %%
start = (dt.datetime.now(tz=dt.timezone.utc) - dt.timedelta(days=HISTORY)).strftime("%Y-%m-%d %H:%M:%S")
end = dt.datetime.now(tz=dt.timezone.utc).strftime("%Y-%m-%d %H:%M:%S")
granularity = 'M1'

# %%
print(start)
print(end)
# Out:
# 2021-02-24 07:45:57
# 2021-05-25 07:45:57

# %%
raw = api.get_history(instrument, start = start, end = end, granularity = granularity, price = 'M')
raw.tail()
# Out:
#                            o        h        l        c  volume  complete
# time
# 2021-05-25 07:42:00  108.668  108.668  108.644  108.645      79      True
# 2021-05-25 07:43:00  108.644  108.655  108.638  108.654      58      True
# 2021-05-25 07:44:00  108.652  108.676  108.650  108.674      81      True
# 2021-05-25 07:45:00  108.676  108.694  108.676  108.693     110      True
# 2021-05-25 07:45:00  108.676  108.694  108.676  108.693     110      True

# %%
data = raw[['o', 'h', 'l', 'c']]
data = data.resample(BAR_LENGTH).agg({'o': 'first', 
                                 'h': 'max', 
                                 'l': 'min', 
                                 'c': 'last'})
data.fillna(method='ffill', inplace=True)
data = data.iloc[:-1]
data.tail()
# Out:
#                            o        h        l        c
# time
# 2021-05-25 06:30:00  108.732  108.740  108.624  108.646
# 2021-05-25 06:45:00  108.647  108.672  108.628  108.668
# 2021-05-25 07:00:00  108.670  108.686  108.560  108.620
# 2021-05-25 07:15:00  108.619  108.637  108.576  108.580
# 2021-05-25 07:30:00  108.578  108.676  108.576  108.674

# %%
data.shape
# Out:
# (8640, 4)

# %% [markdown]
# Transaction cost estimation in percentage terms to adjust portfolio returns when required.

# %%
mean = raw['c'].mean()
ptc = spread / mean
print('Percentage Transaction Cost: {:.3f}%'.format(ptc*100))
# Out:
# Percentage Transaction Cost: 0.007%

# %% [markdown]
# ## Data Exploratory

# %%
data.c.plot(title=instrument, ylabel='Price');

# %% [markdown]
# ## Feature Selection
#
# Set lookback window for 12 hours of 15-min periods.  This is 48 15-min periods.

# %%
window = WINDOW
print('Lookback window: {}'.format(window))
# Out:
# Lookback window: 48

# %% [markdown]
# Create technical indicators as features for model training and prediction.  Indicator types include:
# - Volatility
# - Momentum
# - Trend

# %%
from func_ta import calcTA

# %%
ohlc = data.columns.to_list()
data = calcTA(data, window, volatility=True, basic=False, momentum=True, trend=True)
selected_features = [cols for cols in data if cols not in ohlc]
', '.join(selected_features)
# Out:
# 'return, vol, rsi14, roc12, wr14, aoi5_34, ppo26_12_9, stochoscill14_3, tsi25_13, ultimateosc, kama10_2_30, macd, macd_diff, macd_signal, adx, adx_neg, adx_pos, aroon_down, aroon_indicator, aroon_up, dpo, ema_indicator, ichimoku_a, ichimoku_b, ichimoku_base_line, ichimoku_conversion_line, kst, kst_diff, kst_sig, mass_index, psar, psar_down_indicator, psar_up_indicator, sma_indicator, trix, vortex_indicator_diff, vortex_indicator_neg, vortex_indicator_pos, wma, bb_hband, bb_high, bb_lband, bb_low, bb_mavg, bb_wband, dc_hband, dc_lband, dc_mband, dc_pband, dc_wband, kc_hband, kc_hband_ind, kc_lband, kc_lband_ind, kc_mband, kc_pband, kc_wband, ulcer14, atr'

# %%
data.shape
# Out:
# (8592, 63)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Using only lagged features are used for model training to predict direction movement in the next period.  This is to ensure that there are no data leakages.

# %%
lags = LAGS
lags_range = range(1, lags + 1)

# %%
features = []
for f in selected_features:
    for lag in lags_range:  ## ensure no data leakage
        col = f'{f}_lag_{lag}'
        data[col] = data[f].shift(lag)
        features.append(col)
        
data.dropna(inplace=True)

# %%
print('Features for model training: {}'.format(", ".join(features)))
# Out:
# Features for model training: return_lag_1, return_lag_2, return_lag_3, return_lag_4, return_lag_5, return_lag_6, vol_lag_1, vol_lag_2, vol_lag_3, vol_lag_4, vol_lag_5, vol_lag_6, rsi14_lag_1, rsi14_lag_2, rsi14_lag_3, rsi14_lag_4, rsi14_lag_5, rsi14_lag_6, roc12_lag_1, roc12_lag_2, roc12_lag_3, roc12_lag_4, roc12_lag_5, roc12_lag_6, wr14_lag_1, wr14_lag_2, wr14_lag_3, wr14_lag_4, wr14_lag_5, wr14_lag_6, aoi5_34_lag_1, aoi5_34_lag_2, aoi5_34_lag_3, aoi5_34_lag_4, aoi5_34_lag_5, aoi5_34_lag_6, ppo26_12_9_lag_1, ppo26_12_9_lag_2, ppo26_12_9_lag_3, ppo26_12_9_lag_4, ppo26_12_9_lag_5, ppo26_12_9_lag_6, stochoscill14_3_lag_1, stochoscill14_3_lag_2, stochoscill14_3_lag_3, stochoscill14_3_lag_4, stochoscill14_3_lag_5, stochoscill14_3_lag_6, tsi25_13_lag_1, tsi25_13_lag_2, tsi25_13_lag_3, tsi25_13_lag_4, tsi25_13_lag_5, tsi25_13_lag_6, ultimateosc_lag_1, ultimateosc_lag_2, ultimateosc_lag_3, ultimateosc_lag_4, ultimateosc_lag_5, ultimateosc_lag_6, kama10_2_30_lag_1, kama10_2_30_lag_2, kama10_
# ...

# %% [markdown]
# ## Target Labeling

# %% [markdown]
# Categorise the target to **direction**.  Note that this will cause in imbalanced dataset on a multiclassification problem in which we will try to fix via upsampling later.
#
# | Label | Description |
# | :-: | :-- |
# | 0 | Negative return in the next time step |
# | 1 | Positive return in the next time step |

# %%
target = 'direction'
data[target] = np.where(data['return'] > 0, 1, 0)

# %%
print('Target for model training: {}'.format(target))
# Out:
# Target for model training: direction

# %%
data.tail()
# Out:
#                            o        h        l        c    return       vol  \
# time
# 2021-05-25 06:30:00  108.732  108.740  108.624  108.646 -0.000800  0.000250
# 2021-05-25 06:45:00  108.647  108.672  108.628  108.668  0.000202  0.000252
# 2021-05-25 07:00:00  108.670  108.686  108.560  108.620 -0.000442  0.000259
# 2021-05-25 07:15:00  108.619  108.637  108.576  108.580 -0.000368  0.000264
# 2021-05-25 07:30:00  108.578  108.676  108.576  108.674  0.000865  0.000294
#
#                          rsi14     roc12       wr14   aoi5_34  ppo26_12_9  \
# time
# 2021-05-25 06:30:00  34.637389 -0.066226 -86.585366 -0.013465   -0.010863
# 2021-05-25 06:45:00  39.108219 -0.036796 -73.170732 -0.029429   -0.014272
# 2021-05-25 07:00:00  33.693154 -0.066242 -73.684211 -0.053356   -0.020304
# 2021-05-25 07:15:00  29.969125 -0.155404 -91.228070 -0.077976   -0.027735
# 2021-05-25 07:30:00  45.276420 -0.059776 -50.000000 -0.095588   -0.026342
#
# ...

# %% [markdown]
# Data Prepared!

# %% [markdown]
# ## Data Preparation for Model Training

# %% [markdown]
# ### Out-of-Sample dataset for Testing
#
# Blue data for model training.  Red data for model testing and performance analysis.  Given that there are 2 years worth of history, choosing first half for training and second half for testing.

# %%
split = int(len(data) * 0.8)
train = data.iloc[:split].copy()
test = data.iloc[split:].copy()

# %%
ax = train['c'].plot(label='Training', legend=True)
plt.axvline(train.index[-1], ls='--')
test['c'].plot(ax=ax, style='-.', label='Test', legend=True);

# %% [markdown]
# ### Dataset for Training and Validation
#
# Focusing on data used for model training.  Splitting the data into train and validation datasets with a 4:1 ratio.  Note that resampling will only be done on train dataset.

# %%
X = train[features]
y = train[target]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)

# %% [markdown]
# ### Normalising the datasets
#
# - Fit and Transform on the training dataset
# - Transform only on the validation dataset using the scaler fitted with training dataset

# %%
col_toscale = X_train.columns.tolist()
print('List of columns to scale: {}'.format(col_toscale))
# Out:
# List of columns to scale: ['return_lag_1', 'return_lag_2', 'return_lag_3', 'return_lag_4', 'return_lag_5', 'return_lag_6', 'vol_lag_1', 'vol_lag_2', 'vol_lag_3', 'vol_lag_4', 'vol_lag_5', 'vol_lag_6', 'rsi14_lag_1', 'rsi14_lag_2', 'rsi14_lag_3', 'rsi14_lag_4', 'rsi14_lag_5', 'rsi14_lag_6', 'roc12_lag_1', 'roc12_lag_2', 'roc12_lag_3', 'roc12_lag_4', 'roc12_lag_5', 'roc12_lag_6', 'wr14_lag_1', 'wr14_lag_2', 'wr14_lag_3', 'wr14_lag_4', 'wr14_lag_5', 'wr14_lag_6', 'aoi5_34_lag_1', 'aoi5_34_lag_2', 'aoi5_34_lag_3', 'aoi5_34_lag_4', 'aoi5_34_lag_5', 'aoi5_34_lag_6', 'ppo26_12_9_lag_1', 'ppo26_12_9_lag_2', 'ppo26_12_9_lag_3', 'ppo26_12_9_lag_4', 'ppo26_12_9_lag_5', 'ppo26_12_9_lag_6', 'stochoscill14_3_lag_1', 'stochoscill14_3_lag_2', 'stochoscill14_3_lag_3', 'stochoscill14_3_lag_4', 'stochoscill14_3_lag_5', 'stochoscill14_3_lag_6', 'tsi25_13_lag_1', 'tsi25_13_lag_2', 'tsi25_13_lag_3', 'tsi25_13_lag_4', 'tsi25_13_lag_5', 'tsi25_13_lag_6', 'ultimateosc_lag_1', 'ultimateosc_lag_2', 'ultimateos
# ...

# %%
def processStdScaler(train, valid, columns):
    
    train_scaled = train.copy()
    valid_scaled = valid.copy()

    scaler = StandardScaler()
    scaler.fit(train[columns])
    train_scaled[columns] = scaler.transform(train[columns])
    valid_scaled[columns] = scaler.transform(valid[columns])

    return train_scaled, valid_scaled, scaler

# %%
X_train_std, X_valid_std, scaler = processStdScaler(X_train, X_valid, col_toscale)

# %%
X_train = X_train_std
X_valid = X_valid_std

# %% [markdown]
# ### Resampling the Training dataset
# Because of imbalanced target variable, resampling is only done on the training dataset.  Note that upsampling is conducted after the training dataset is normalised.

# %%
from sklearn.utils import resample

def upsample_byCol(data, column, code):
    maxN = data.groupby(column).size().max()

    df = data[data[column] == code]
    num = maxN - df.shape[0]
    if num > 0:
        df_more = resample(df, replace=True, n_samples=num, random_state=SEED)
        df = pd.concat([df, df_more])
    return df

# %%
Xy_train = pd.concat([X_train, y_train], axis = 1)

# %%
Xy_train.groupby(target).size()
# Out:
# direction
# 0    3457
# 1    2037
# dtype: int64

# %%
train_resample = []

return_ranges = Xy_train[target].unique()

for return_range in return_ranges:
    code_resampled = upsample_byCol(Xy_train, target, return_range)
    train_resample.append(code_resampled)
    
Xy_train = pd.concat(train_resample).reset_index(drop=True)
Xy_train = Xy_train.sample(frac=1).reset_index(drop=True)

# %%
Xy_train.groupby(target).size()
# Out:
# direction
# 0    3457
# 1    3457
# dtype: int64

# %% [markdown]
# After ensuring a balanced training dataset, prepare the features and target of the training and validation dataset respectively.

# %%
X_train = Xy_train[features]
y_train = Xy_train[target]

# %% [markdown]
# Expect class weights to be balanced due to upsampling.  If upsampling is not done, then the class weights during model training is important.

# %%
from sklearn.utils import class_weight
class_weights_dict = dict(zip(np.unique(y_train), 
                         class_weight.compute_class_weight('balanced', 
                                                           np.unique(y_train), y_train)))

# %%
class_weights_dict
# Out:
# {0: 1.0, 1: 1.0}

# %% [markdown]
# ### Prepare Training and Validation dataset for GridSearch
#
# This will have to be done separately because we need the grid search to tune the parameters by validating against a dataset we provide and not automatically sampled from the training dataset that has been resampled.  We want samples in the validation dataset to be unseen in the training dataset.
#
# In order to do this properly for GridSearchCV, we need to use PredefinedSplit and fit GridSearchCV with the full dataset.

# %%
Xy_trainGS = X_train.join(y_train)
Xy_validGS = X_valid.join(y_valid)

# %%
from sklearn.model_selection import PredefinedSplit

# Create a list where train data indices are -1 and validation data indices are 0
# eg: split_index = [-1 if x in X_train.index else 0 for x in X.index]
split_index = [-1] * Xy_trainGS.shape[0] + [0] * Xy_validGS.shape[0] 

# Use the list to create PredefinedSplit
pds_GridSearch = PredefinedSplit(test_fold = split_index)

# %%
Xy_GS = pd.concat([Xy_trainGS, Xy_validGS]).reset_index(drop=True) 
X_GS = Xy_GS[features]
y_GS = Xy_GS[target]

# %% [markdown]
# ### Finalising the Datasets

# %% [markdown]
# Keeping a copy of the validation target dataframe for confusion matrix later

# %%
X_valid_org = X_valid.copy()
y_valid_org = y_valid.copy()
y_valid_org = y_valid_org.to_frame()

# %% [markdown]
# Convert to numpy arrays for tensorflow keras model training

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_valid = np.array(X_valid)
y_valid = np.array(y_valid)
X_GS = np.array(X_GS)
y_GS = np.array(y_GS)

# %%
y_train = y_train.reshape(-1,1)
y_valid = y_valid.reshape(-1,1)
y_GS = y_GS.reshape(-1,1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_GS.shape)
print(y_GS.shape)
# Out:
# (6914, 354)
# (6914, 1)
# (1374, 354)
# (1374, 1)
# (8288, 354)
# (8288, 1)

# %% [markdown]
# ## Building Deep Learning Model

# %% [markdown]
# Loading the model libraries

# %%
import tensorflow as tf

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score, ShuffleSplit, cross_validate
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l1

# %%
INPUTS = X_train.shape[1]
TRAINING_OBSERVATIONS = X_train.shape[0]
NUM_OF_OUTPUTS = 1
print('Number of inputs to neural network: {}'.format(INPUTS))
print('Number of training observations: {}'.format(TRAINING_OBSERVATIONS))
print('Number of target outputs: {}'.format(NUM_OF_OUTPUTS))
# Out:
# Number of inputs to neural network: 354
# Number of training observations: 6914
# Number of target outputs: 1

# %% [markdown]
# ### Defining model structure

# %%
def build_model(nodes=(4,4,4), activation='relu', learning_rate=0.002, 
                regularize=False, reg=l1(0.0005), input_dropout=0.05):
    
    if not regularize:
        reg = None

    model = Sequential()

#   kernel_initializer='normal'    
    model.add(Dense(nodes[0], input_shape=(INPUTS,), 
                    activation=activation,
                    activity_regularizer=reg, 
                    kernel_initializer='he_uniform'))
    model.add(Dropout(input_dropout, seed=SEED))
    
    for node in nodes[1:]:
        model.add(Dense(node, activation=activation, 
                        activity_regularizer=reg, 
                        kernel_initializer='he_uniform'))
        model.add(Dropout(input_dropout, seed=SEED))

#   activation='softmax'
    model.add(Dense(NUM_OF_OUTPUTS, activation='sigmoid'))

    opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.99, epsilon=None, decay=0.0, amsgrad=False)

#   loss='categorical_crossentropy'
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    return model

# %% [markdown]
# ### Hyperparameter Tuning
# Setting the GridSearchCV parameters.  Limiting the number of parameters to tune here as the computation resources on the JoinQuant research environment is limited.
#
# **Tunable Parameters**
# 1. Number of the dense layer in the deep learning model
# 2. Activation function
# 3. Batch Size
# 4. Number of Training Epoch
# 5. Learning Rate for Optimiser
# 6. Dropout Ratio for the dropout layer

# %%
import itertools

layer1 = [32,64]
layer2 = [32,64]
layers = [layer1, layer2]

NODES_LIST = list(itertools.product(*layers))
ACTIVATION_LIST = ['relu', 'tanh'] ## 'relu', 'sigmoid', 'leaky_relu'
BATCHSIZE_LIST = [2048, 4096]
EPOCHS_LIST = [50]
LEARNINGRATE_LIST = [0.005, 0.001, 0.0005]
INPUTDROPOUT_LIST = [0, 0.3, 0.5]

# Define the parameters to try out
params = {'nodes': NODES_LIST, 
          'activation': ACTIVATION_LIST, 
          'batch_size': BATCHSIZE_LIST, 
          'epochs': EPOCHS_LIST, 
          'input_dropout': INPUTDROPOUT_LIST, 
          'learning_rate': LEARNINGRATE_LIST}

print(params)
# Out:
# {'nodes': [(32, 32), (32, 64), (64, 32), (64, 64)], 'activation': ['relu', 'tanh'], 'batch_size': [2048, 4096], 'epochs': [50], 'input_dropout': [0, 0.3, 0.5], 'learning_rate': [0.005, 0.001, 0.0005]}

# %%
# Import KerasClassifier from keras wrappers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# Create a KerasClassifier
grid_buildmodel = KerasClassifier(build_fn = build_model)

grid_search = GridSearchCV(grid_buildmodel, param_grid = params, 
                           cv = pds_GridSearch, scoring='roc_auc',
                           verbose=0, return_train_score=True)

# %% [markdown]
# Fit using the GS dataset because using PredefinedSplit here

# %%
# %%capture --no-display gridsearchlog
# %time grid_search.fit(X_GS, y_GS, class_weight = class_weights_dict)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6801 - accuracy: 0.5858
# Epoch 2/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5525 - accuracy: 0.6903
# Epoch 3/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5303 - accuracy: 0.7083
# Epoch 4/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5251 - accuracy: 0.7103
# Epoch 5/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5171 - accuracy: 0.7229
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5107 - accuracy: 0.7224
# Epoch 7/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.7271
# Epoch 8/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.7317
# Epoch 9/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4972 - accuracy: 0.7330
# Epoch 10/50
# ...

# %%
best_parameters = grid_search.best_params_
best_score = grid_search.best_score_

print('The best score: {:.3f}'.format(best_score))
print('The optimal parameters: {}'.format(best_parameters))
# Out:
# The best score: 0.736
# The optimal parameters: {'activation': 'relu', 'batch_size': 2048, 'epochs': 50, 'input_dropout': 0.3, 'learning_rate': 0.001, 'nodes': (64, 32)}

# %% [markdown]
# ### Building Best Model
#
# Updating the model to use the best hyperparameters

# %%
NODES = best_parameters['nodes']
LR = best_parameters['learning_rate']
ACTIVATION = best_parameters['activation']
EPOCHS = best_parameters['epochs']
BATCH_SIZE = best_parameters['batch_size']
INPUT_DROPOUT = best_parameters['input_dropout']
PATIENCE = int(EPOCHS * 0.1)    ## To reduce training time.  
                                ## Early stopping when there is no further 
                                ## improvement after 10% of Epoch

# Define a callback to monitor val_mse
monitor_val_acc = EarlyStopping(monitor='val_accuracy', patience=PATIENCE)

# Save the best model
save_model_chkpt = ModelCheckpoint(MODEL_FOLDER + instrument + '_dl_model.hdf5', 
                                   monitor='val_loss', 
                                   save_best_only=True, mode='min')

CALLBACKS = [save_model_chkpt, monitor_val_acc]

model = build_model(nodes=NODES, activation=ACTIVATION, learning_rate=LR, \
                    input_dropout=INPUT_DROPOUT)
model.summary()
# Out:
# Model: "sequential_145"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_435 (Dense)            (None, 64)                22720
# _________________________________________________________________
# dropout_290 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_436 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_291 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_437 (Dense)            (None, 1)                 33
# ...
# Total params: 24,833
# Trainable params: 24,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=EPOCHS, 
                    validation_data=(X_valid, y_valid), 
                    batch_size=BATCH_SIZE, verbose=0,
                    class_weight = class_weights_dict,
                    callbacks=CALLBACKS)

# %% [markdown]
# Plotting the training and validation accuracy and losses over the epochs.  For the model to be training well, the training and validation accuracy should increase and then flatten as epoch increases.  Expect training accuracy to be marginally better than validation.  We should not overfit the model.  Training and validation accuracy should reduce.  Training should stop if the validation losses widens.

# %%
def plot_results(data, val_data, title='Results', N=0.05):
    upper_limit = np.max(val_data + data)*(1+N)
    lower_limit = np.min(val_data + data)*(1-N)
    plt.figure()
    plt.plot(data)
    plt.plot(val_data)
    plt.ylim([lower_limit, upper_limit])
    plt.title(title)
    plt.ylabel(title)
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()

# %%
# Plot train vs validation loss during training
plot_results(history.history['loss'], history.history['val_loss'], 'Model Loss')

# Plot train vs validation accuracy during training
plot_results(history.history['accuracy'], history.history['val_accuracy'], 'Mean Accuracy')

# %%
print('Model Evaluation Loss: {:.3f}'.format(model.evaluate(X_valid, y_valid)[0]))
# Out:
# 43/43 [==============================] - 0s 1ms/step - loss: 0.5660 - accuracy: 0.6237
# Model Evaluation Loss: 0.566

# %%
model.load_weights(MODEL_FOLDER + instrument + '_dl_model.hdf5')
model.evaluate(X_valid, y_valid)
# Out:
# 43/43 [==============================] - 0s 1ms/step - loss: 0.5660 - accuracy: 0.6237
# [0.5659764409065247, 0.6237263679504395]

# %% [markdown]
# ### Model Performance

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# Append the predicted results with the actual validation results for comparsion

# %%
y_valid_org['predicted_direction'] = np.where(model.predict(X_valid) > 0.5, 1, 0)

# %%
y_valid_org.predicted_direction.value_counts()
# Out:
# 1    986
# 0    388
# Name: predicted_direction, dtype: int64

# %% [markdown]
# #### Confusion Matrix

# %% [markdown]
# For a good enough trading algorithm, accuracy in both long and short predictions are equally important.  As such, we should focus on the f1 accuracy score.  The higher the better.

# %%
#importing confusion matrix

from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_valid_org['direction'], y_valid_org['predicted_direction'])

plot_confusion_matrix(confusion, ['Short', 'Long'], False)
plt.show()

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_valid_org['direction'], y_valid_org['predicted_direction'], 
                            target_names=['Short', 'Long']))
# Out:
#               precision    recall  f1-score   support
#
#        Short       0.95      0.43      0.59       865
#         Long       0.50      0.96      0.65       509
#
#     accuracy                           0.62      1374
#    macro avg       0.72      0.69      0.62      1374
# weighted avg       0.78      0.62      0.61      1374

# %% [markdown]
# ## Trading Performance
#
# Measuring the trading performance first on training data and then on out-of-sample test data.  Long and short positions are taken according to model prediction and the returns of each time step is calculated.
#
# The cumulative return of the trading portfolio (**strategy**) is finally calculated and compared with the asset cumulative return (**return**) over the same period.
#
# Cumulative return of the tradinng portfolio with transaction cost (**strategy_**) is also calculated to reflect a more realistic representation of the actual performance.
#
# ### On Training Data

# %%
train_ = scaler.transform(train[features])

# %%
train['position'] = np.where(model.predict(train_) > 0.5, 1, 0)

# %%
train['position'] = np.where(train['position'] == 1, 1, -1)

# %%
train['position'].value_counts()
# Out:
#  1    4831
# -1    2037
# Name: position, dtype: int64

# %%
train['strategy'] = train['position'] * train['return']

# %%
train[['return', 'strategy']].sum().apply(np.exp)
# Out:
# return      1.030758
# strategy    1.050177
# dtype: float64

# %%
train[['return', 'strategy']].sum().apply(np.exp)  - 1
# Out:
# return      0.030758
# strategy    0.050177
# dtype: float64

# %%
train[['return', 'strategy']].cumsum().apply(np.exp).plot();

# %% [markdown]
# The plot above shows the model's trading strategy outperforms that of asset slightly.

# %% [markdown]
# ### On Out-of-Sample Data

# %%
model.load_weights(MODEL_FOLDER + instrument + '_dl_model.hdf5')

# %%
test_ = scaler.transform(test[features])

# %%
model.evaluate(test_, test[target])
# Out:
# 54/54 [==============================] - 0s 1ms/step - loss: 0.5186 - accuracy: 0.6508
# [0.5186200141906738, 0.6507567167282104]

# %%
test['position'] = np.where(model.predict(test_) > 0.5, 1, -1)

# %%
test['position'].value_counts()
# Out:
#  1    1071
# -1     647
# Name: position, dtype: int64

# %%
test['strategy'] = test['position'] * test['return']

# %%
test[['return', 'strategy']].sum().apply(np.exp)
# Out:
# return      0.995949
# strategy    0.997730
# dtype: float64

# %%
test[['return', 'strategy']].sum().apply(np.exp) - 1
# Out:
# return     -0.004051
# strategy   -0.002270
# dtype: float64

# %%
test[['return', 'strategy']].cumsum().apply(np.exp).plot();

# %% [markdown]
# On out-of-sample data, the model's trading strategy still beats the benckmark (asset's return).

# %%
sum(test['position'].diff() != 0) + 1
# Out:
# 66

# %% [markdown]
# There are 212 switches of trades. For example, short to long position or vice versa.  This means that there are 212 trades executed.

# %%
test['strategy_'] = np.where(test['position'].diff() != 0,
                      test['strategy'] - ptc, test['strategy'])

# %%
test['strategy_'].iloc[-1] -= ptc

# %%
test[['return', 'strategy', 'strategy_']].sum().apply(np.exp)
# Out:
# return       0.995949
# strategy     0.997730
# strategy_    0.992900
# dtype: float64

# %%
test[['return', 'strategy', 'strategy_']].sum().apply(np.exp) - 1
# Out:
# return      -0.004051
# strategy    -0.002270
# strategy_   -0.007100
# dtype: float64

# %%
test[['return', 'strategy', 'strategy_']].cumsum().apply(np.exp).plot();

# %% [markdown]
# However, once transaction cost is taken into consideration, the strategy underperforms that of the asset.  Transaction cost is high because the number of trades due over the testing period is high.  A longer time step could reduced the total transaction cost.

# %%
test['predicted_direction'] = np.where(model.predict(test_) > 0.5, 1, 0)

# %%
erk.summary_stats(test[['return', 'strategy', 'strategy_']], 
                  riskfree_rate=RISK_FREE_RATE, periods_per_year=PERIODS_PER_YEAR)
# Out:
#            Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# return             -0.056689        0.049046 -1.934221  66.503457
# strategy           -0.032663        0.049047 -1.874028  66.525082
# strategy_          -0.096557        0.049171 -1.975549  68.544869
#
#            Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# return                    0.000268            0.000728     -1.532936
# strategy                  0.000263            0.000725     -1.052656
# strategy_                 0.000260            0.000728     -2.323962
#
#            Max Drawdown
# return        -0.010700
# strategy      -0.008283
# strategy_     -0.011994

# %%
#importing confusion matrix

from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(test['direction'], test['predicted_direction'])

plot_confusion_matrix(confusion, ['Short','Long'], False)
plt.show()

# %%
test[['position', 'direction', 'predicted_direction']]
# Out:
#                      position  direction  predicted_direction
# time
# 2021-05-07 10:15:00         1          0                    1
# 2021-05-07 10:30:00         1          1                    1
# 2021-05-07 10:45:00        -1          1                    0
# 2021-05-07 11:00:00        -1          1                    0
# 2021-05-07 11:15:00        -1          0                    0
# ...                       ...        ...                  ...
# 2021-05-25 06:30:00         1          0                    1
# 2021-05-25 06:45:00         1          1                    1
# 2021-05-25 07:00:00         1          0                    1
# 2021-05-25 07:15:00         1          0                    1
# 2021-05-25 07:30:00         1          1                    1
#
# [1718 rows x 3 columns]

# %% [markdown]
# ## Concluding Remarks
#
# 1. The above analysis shows how one can build a deep learning model to execute trades with the objective of outperforming the benchmark.
# 2. How well the model performs depends on many factors.  For instance, the amount of historical data for model training, the time step to use to make a trading decision, etc.
# 3. The longer the history, the model is trained on data points that are further away from current events.  The shorter each time step, you are exposing yourself to more trading decisions and hence potentially higher transaction cost.
# 4. Selection of trading asset is also important.  Different assets have different transaction cost (bid ask spread).  Assets with larger bid-ask spread may not be easily profitable.
# 5. Models will have to be tuned and retrained with latest data to ensure relevancy to recent market events.
